# %% [markdown]
# # SS MRF

# %%
# Import libraries
from swolfpy_processmodels import SS_MRF

import swolfpy as sp
import swolfpy_inputdata as spid
import swolfpy_processmodels as sppm

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy_financial as npf

# Set font for plots
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "12"

from IPython.display import Image

# Set specs for pandas
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_rows', 500)
pd.set_option('display.precision', 2)

# %%
model = SS_MRF()
model.calc()
report = model.report()

# %% [markdown]
# ## Waste Products

# %%
Waste_products = pd.DataFrame(report['Waste']).transpose()
Waste_products
# Out:
#                                Other_Residual  LDPE_Film   OCC  Mixed_Paper  \
# Yard_Trimmings_Leaves          1.00            0.00       0.00  0.00
# Yard_Trimmings_Grass           1.00            0.00       0.00  0.00
# Yard_Trimmings_Branches        1.00            0.00       0.00  0.00
# Food_Waste_Vegetable           1.00            0.00       0.00  0.00
# Food_Waste_Non_Vegetable       1.00            0.00       0.00  0.00
# Wood                           1.00            0.00       0.00  0.00
# Wood_Other                     1.00            0.00       0.00  0.00
# Textiles                       1.00            0.00       0.00  0.00
# Rubber_Leather                 1.00            0.00       0.00  0.00
# Newsprint                      0.12            0.00       0.00  0.88
# Corr_Cardboard                 0.12            0.00       0.88  0.00
# Office_Paper                   0.12            0.00       0.00  0.88
# Magazines                      0.12            0.00       0.00  0.88
# Third_Class_Mail               0.12            0.00       0.00  0.88
# Folding_Containers             0.12            0.00       0.00  0.88
# Paper_Bags                     0.12            0.00       0.00  0.88
# Mixed_Paper                    0.12            0.00       0.00  0.88
# Paper_Non_recyclable           1.00            0.00       0.00  0.00
# HDPE_Translucent_Containers    0.02            0.00       0.00  0.00
# HDPE_Pigmented_Containers      0.02            0.00       0.00  0.00
# PET_Containers                 0.12            0.00       0.00  0.00
# Plastic_Other_1_Polypropylene  1.00            0.00       0.00  0.00
# Plastic_Other_2                1.00            0.00       0.00  0.00
# Mixed_Plastic                  1.00            0.00       0.00  0.00
# Plastic_Film                   0.23            0.77       0.00  0.00
# Plastic_Non_Recyclable         1.00            0.00       0.00  0.00
# Ferrous_Cans                   0.12            0.00       0.00  0.00
# Ferrous_Metal_Other            0.12            0.00       0.00  0.00
# Aluminum_Cans                  0.12            0.00       0.00  0.00
# Aluminum_Foil                  0.12            0.00       0.00  0.00
# Aluminum_Other                 0.12            0.00       0.00  0.00
# Ferrous_Non_recyclable         0.12            0.00       0.00  0.00
# Al_Non_recyclable              0.12            0.00       0.00  0.00
# Glass_Brown                    0.23            0.00       0.00  0.00
# Glass_Green                    0.23            0.00       0.00  0.00
# Glass_Clear                    0.23            0.00       0.00  0.00
# Mixed_Glass                    1.00            0.00       0.00  0.00
# Glass_Non_recyclable           1.00            0.00       0.00  0.00
# Misc_Organic                   1.00            0.00       0.00  0.00
# Misc_Inorganic                 1.00            0.00       0.00  0.00
# E_waste                        1.00            0.00       0.00  0.00
# Bottom_Ash                     1.00            0.00       0.00  0.00
# Fly_Ash                        1.00            0.00       0.00  0.00
# Diapers_and_sanitary_products  1.00            0.00       0.00  0.00
#
#                                ONP  OFF  Fiber_Other  Brown_glass  \
# Yard_Trimmings_Leaves          0.0  0.0  0.0          0.00
# Yard_Trimmings_Grass           0.0  0.0  0.0          0.00
# Yard_Trimmings_Branches        0.0  0.0  0.0          0.00
# Food_Waste_Vegetable           0.0  0.0  0.0          0.00
# Food_Waste_Non_Vegetable       0.0  0.0  0.0          0.00
# Wood                           0.0  0.0  0.0          0.00
# Wood_Other                     0.0  0.0  0.0          0.00
# Textiles                       0.0  0.0  0.0          0.00
# Rubber_Leather                 0.0  0.0  0.0          0.00
# Newsprint                      0.0  0.0  0.0          0.00
# Corr_Cardboard                 0.0  0.0  0.0          0.00
# Office_Paper                   0.0  0.0  0.0          0.00
# Magazines                      0.0  0.0  0.0          0.00
# Third_Class_Mail               0.0  0.0  0.0          0.00
# Folding_Containers             0.0  0.0  0.0          0.00
# Paper_Bags                     0.0  0.0  0.0          0.00
# Mixed_Paper                    0.0  0.0  0.0          0.00
# Paper_Non_recyclable           0.0  0.0  0.0          0.00
# HDPE_Translucent_Containers    0.0  0.0  0.0          0.00
# HDPE_Pigmented_Containers      0.0  0.0  0.0          0.00
# PET_Containers                 0.0  0.0  0.0          0.00
# Plastic_Other_1_Polypropylene  0.0  0.0  0.0          0.00
# Plastic_Other_2                0.0  0.0  0.0          0.00
# Mixed_Plastic                  0.0  0.0  0.0          0.00
# Plastic_Film                   0.0  0.0  0.0          0.00
# Plastic_Non_Recyclable         0.0  0.0  0.0          0.00
# Ferrous_Cans                   0.0  0.0  0.0          0.00
# Ferrous_Metal_Other            0.0  0.0  0.0          0.00
# Aluminum_Cans                  0.0  0.0  0.0          0.00
# Aluminum_Foil                  0.0  0.0  0.0          0.00
# Aluminum_Other                 0.0  0.0  0.0          0.00
# Ferrous_Non_recyclable         0.0  0.0  0.0          0.00
# Al_Non_recyclable              0.0  0.0  0.0          0.00
# Glass_Brown                    0.0  0.0  0.0          0.77
# Glass_Green                    0.0  0.0  0.0          0.00
# Glass_Clear                    0.0  0.0  0.0          0.00
# Mixed_Glass                    0.0  0.0  0.0          0.00
# Glass_Non_recyclable           0.0  0.0  0.0          0.00
# Misc_Organic                   0.0  0.0  0.0          0.00
# Misc_Inorganic                 0.0  0.0  0.0          0.00
# E_waste                        0.0  0.0  0.0          0.00
# Bottom_Ash                     0.0  0.0  0.0          0.00
# Fly_Ash                        0.0  0.0  0.0          0.00
# Diapers_and_sanitary_products  0.0  0.0  0.0          0.00
#
#                                Clear_glass  Green_glass  Mixed_Glass   PET  \
# Yard_Trimmings_Leaves          0.00         0.00         0.0          0.00
# Yard_Trimmings_Grass           0.00         0.00         0.0          0.00
# Yard_Trimmings_Branches        0.00         0.00         0.0          0.00
# Food_Waste_Vegetable           0.00         0.00         0.0          0.00
# Food_Waste_Non_Vegetable       0.00         0.00         0.0          0.00
# Wood                           0.00         0.00         0.0          0.00
# Wood_Other                     0.00         0.00         0.0          0.00
# Textiles                       0.00         0.00         0.0          0.00
# Rubber_Leather                 0.00         0.00         0.0          0.00
# Newsprint                      0.00         0.00         0.0          0.00
# Corr_Cardboard                 0.00         0.00         0.0          0.00
# Office_Paper                   0.00         0.00         0.0          0.00
# Magazines                      0.00         0.00         0.0          0.00
# Third_Class_Mail               0.00         0.00         0.0          0.00
# Folding_Containers             0.00         0.00         0.0          0.00
# Paper_Bags                     0.00         0.00         0.0          0.00
# Mixed_Paper                    0.00         0.00         0.0          0.00
# Paper_Non_recyclable           0.00         0.00         0.0          0.00
# HDPE_Translucent_Containers    0.00         0.00         0.0          0.00
# HDPE_Pigmented_Containers      0.00         0.00         0.0          0.00
# PET_Containers                 0.00         0.00         0.0          0.88
# Plastic_Other_1_Polypropylene  0.00         0.00         0.0          0.00
# Plastic_Other_2                0.00         0.00         0.0          0.00
# Mixed_Plastic                  0.00         0.00         0.0          0.00
# Plastic_Film                   0.00         0.00         0.0          0.00
# Plastic_Non_Recyclable         0.00         0.00         0.0          0.00
# Ferrous_Cans                   0.00         0.00         0.0          0.00
# Ferrous_Metal_Other            0.00         0.00         0.0          0.00
# Aluminum_Cans                  0.00         0.00         0.0          0.00
# Aluminum_Foil                  0.00         0.00         0.0          0.00
# Aluminum_Other                 0.00         0.00         0.0          0.00
# Ferrous_Non_recyclable         0.00         0.00         0.0          0.00
# Al_Non_recyclable              0.00         0.00         0.0          0.00
# Glass_Brown                    0.00         0.00         0.0          0.00
# Glass_Green                    0.00         0.77         0.0          0.00
# Glass_Clear                    0.77         0.00         0.0          0.00
# Mixed_Glass                    0.00         0.00         0.0          0.00
# Glass_Non_recyclable           0.00         0.00         0.0          0.00
# Misc_Organic                   0.00         0.00         0.0          0.00
# Misc_Inorganic                 0.00         0.00         0.0          0.00
# E_waste                        0.00         0.00         0.0          0.00
# Bottom_Ash                     0.00         0.00         0.0          0.00
# Fly_Ash                        0.00         0.00         0.0          0.00
# Diapers_and_sanitary_products  0.00         0.00         0.0          0.00
#
#                                HDPE_P  HDPE_T    Fe    Al
# Yard_Trimmings_Leaves          0.00    0.00    0.00  0.00
# Yard_Trimmings_Grass           0.00    0.00    0.00  0.00
# Yard_Trimmings_Branches        0.00    0.00    0.00  0.00
# Food_Waste_Vegetable           0.00    0.00    0.00  0.00
# Food_Waste_Non_Vegetable       0.00    0.00    0.00  0.00
# Wood                           0.00    0.00    0.00  0.00
# Wood_Other                     0.00    0.00    0.00  0.00
# Textiles                       0.00    0.00    0.00  0.00
# Rubber_Leather                 0.00    0.00    0.00  0.00
# Newsprint                      0.00    0.00    0.00  0.00
# Corr_Cardboard                 0.00    0.00    0.00  0.00
# Office_Paper                   0.00    0.00    0.00  0.00
# Magazines                      0.00    0.00    0.00  0.00
# Third_Class_Mail               0.00    0.00    0.00  0.00
# Folding_Containers             0.00    0.00    0.00  0.00
# Paper_Bags                     0.00    0.00    0.00  0.00
# Mixed_Paper                    0.00    0.00    0.00  0.00
# Paper_Non_recyclable           0.00    0.00    0.00  0.00
# HDPE_Translucent_Containers    0.00    0.98    0.00  0.00
# HDPE_Pigmented_Containers      0.98    0.00    0.00  0.00
# PET_Containers                 0.00    0.00    0.00  0.00
# Plastic_Other_1_Polypropylene  0.00    0.00    0.00  0.00
# Plastic_Other_2                0.00    0.00    0.00  0.00
# Mixed_Plastic                  0.00    0.00    0.00  0.00
# Plastic_Film                   0.00    0.00    0.00  0.00
# Plastic_Non_Recyclable         0.00    0.00    0.00  0.00
# Ferrous_Cans                   0.00    0.00    0.88  0.00
# Ferrous_Metal_Other            0.00    0.00    0.88  0.00
# Aluminum_Cans                  0.00    0.00    0.00  0.88
# Aluminum_Foil                  0.00    0.00    0.00  0.88
# Aluminum_Other                 0.00    0.00    0.00  0.88
# Ferrous_Non_recyclable         0.00    0.00    0.88  0.00
# Al_Non_recyclable              0.00    0.00    0.00  0.88
# Glass_Brown                    0.00    0.00    0.00  0.00
# Glass_Green                    0.00    0.00    0.00  0.00
# Glass_Clear                    0.00    0.00    0.00  0.00
# Mixed_Glass                    0.00    0.00    0.00  0.00
# Glass_Non_recyclable           0.00    0.00    0.00  0.00
# Misc_Organic                   0.00    0.00    0.00  0.00
# Misc_Inorganic                 0.00    0.00    0.00  0.00
# E_waste                        0.00    0.00    0.00  0.00
# Bottom_Ash                     0.00    0.00    0.00  0.00
# Fly_Ash                        0.00    0.00    0.00  0.00
# Diapers_and_sanitary_products  0.00    0.00    0.00  0.00

# %%
Waste_products.sum() / Waste_products.shape[0]
# Out:
# Other_Residual    0.57
# LDPE_Film         0.02
# OCC               0.02
# Mixed_Paper       0.14
# ONP               0.00
# OFF               0.00
# Fiber_Other       0.00
# Brown_glass       0.02
# Clear_glass       0.02
# Green_glass       0.02
# Mixed_Glass       0.00
# PET               0.02
# HDPE_P            0.02
# HDPE_T            0.02
# Fe                0.06
# Al                0.08
# dtype: float64

# %%
Waste_products.sum(axis=1)
# Out:
# Yard_Trimmings_Leaves            1.0
# Yard_Trimmings_Grass             1.0
# Yard_Trimmings_Branches          1.0
# Food_Waste_Vegetable             1.0
# Food_Waste_Non_Vegetable         1.0
# Wood                             1.0
# Wood_Other                       1.0
# Textiles                         1.0
# Rubber_Leather                   1.0
# Newsprint                        1.0
# Corr_Cardboard                   1.0
# Office_Paper                     1.0
# Magazines                        1.0
# Third_Class_Mail                 1.0
# Folding_Containers               1.0
# Paper_Bags                       1.0
# Mixed_Paper                      1.0
# Paper_Non_recyclable             1.0
# HDPE_Translucent_Containers      1.0
# HDPE_Pigmented_Containers        1.0
# PET_Containers                   1.0
# Plastic_Other_1_Polypropylene    1.0
# Plastic_Other_2                  1.0
# Mixed_Plastic                    1.0
# Plastic_Film                     1.0
# Plastic_Non_Recyclable           1.0
# Ferrous_Cans                     1.0
# Ferrous_Metal_Other              1.0
# Aluminum_Cans                    1.0
# Aluminum_Foil                    1.0
# Aluminum_Other                   1.0
# Ferrous_Non_recyclable           1.0
# Al_Non_recyclable                1.0
# Glass_Brown                      1.0
# Glass_Green                      1.0
# Glass_Clear                      1.0
# Mixed_Glass                      1.0
# Glass_Non_recyclable             1.0
# Misc_Organic                     1.0
# Misc_Inorganic                   1.0
# E_waste                          1.0
# Bottom_Ash                       1.0
# Fly_Ash                          1.0
# Diapers_and_sanitary_products    1.0
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14, 6))
Waste_products.plot.bar(ax=ax, stacked=True)
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1), ncol=8)
fig.tight_layout()

# %% [markdown]
# ### Cost & GHG emissions

# %%
project_name = 'SS_MRF'
common_data = spid.CommonData()
ProcessMetaData = sppm.ProcessModelsMetaData.ProcessModelsMetaData

Treatment_processes = {}
Treatment_processes['SS_MRF'] = {'input_type':[] , 'model':sppm.SS_MRF()}

# Distance
Processes = ['SS_MRF']
data = sppm.Distance.create_distance_table(process_names=Processes,
                                           transport_modes=['Heavy Duty Truck'],
                                           default_dist=30)

distance = sppm.Distance(data)
demo = sp.Project(project_name, common_data, Treatment_processes, distance)
demo.init_project()
demo.write_project()
demo.group_exchanges()
newparam = []
demo.update_parameters(newparam)
# Out:
# Creating default biosphere
# Writing activities to SQLite3 database:
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applied 2 strategies in 0.00 seconds
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/03/2022 12:14:42
#   Finished: 02/03/2022 12:14:42
#   Total time elapsed: 00:00:00
#   CPU %: 72.40
#   Memory %: 1.34
# Created database: biosphere3
# Creating default LCIA methods
#
# Applying strategy: normalize_units
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applied 4 strategies in 0.96 seconds
# Wrote 850 LCIA methods with 219059 characterization factors
# Creating core data migrations
# Writing activities to SQLite3 database:
#                 ####
#                 ++++++  Writing the Technosphere
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:15
# Title: Writing activities to SQLite3 database:
#   Started: 02/03/2022 12:15:54
#   Finished: 02/03/2022 12:16:10
#   Total time elapsed: 00:00:15
#   CPU %: 43.90
#   Memory %: 1.86
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the SS_MRF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/03/2022 12:16:11
#   Finished: 02/03/2022 12:16:11
#   Total time elapsed: 00:00:00
#   CPU %: 97.70
#   Memory %: 1.86
#
#                   ####
#                   ++++++ Writing the SS_MRF_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/03/2022 12:16:11
#   Finished: 02/03/2022 12:16:12
#   Total time elapsed: 00:00:00
#   CPU %: 67.00
#   Memory %: 1.86
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the SS_MRF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/03/2022 12:16:12
#   Finished: 02/03/2022 12:16:12
#   Total time elapsed: 00:00:00
#   CPU %: 30.00
#   Memory %: 1.86
#
#                   Grouping the exchanges with parameters in Database SS_MRF

# %%
funtional_units = []
for w in common_data.Index:
    funtional_units.append({('SS_MRF', w): 1})

impact_methods = [('IPCC 2013', 'climate change', 'GWP 100a'),
                  ('SwolfPy_Operational_Cost', 'SwolfPy'),
                  ('SwolfPy_Capital_Cost', 'SwolfPy'),
                  ('SwolfPy_Total_Cost', 'SwolfPy')]
LCA_results = demo.setup_LCA('SS_MRF', funtional_units, impact_methods)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 6), sharex=True)
LCA_results.iloc[:, [1, 2]].plot(kind='bar', stacked=True, ax=ax1)
LCA_results.iloc[:, [0]].plot(kind='bar', ax=ax2, color=['g'])
# Out:
# <AxesSubplot:>

# %%
LCA_results
# Out:
#                                              ('IPCC 2013', 'climate change', 'GWP 100a')  \
# ('SS_MRF', 'Yard_Trimmings_Leaves')          39.14
# ('SS_MRF', 'Yard_Trimmings_Grass')           39.14
# ('SS_MRF', 'Yard_Trimmings_Branches')        39.14
# ('SS_MRF', 'Food_Waste_Vegetable')           39.14
# ('SS_MRF', 'Food_Waste_Non_Vegetable')       39.14
# ('SS_MRF', 'Wood')                           39.14
# ('SS_MRF', 'Wood_Other')                     39.14
# ('SS_MRF', 'Textiles')                       39.14
# ('SS_MRF', 'Rubber_Leather')                 39.14
# ('SS_MRF', 'Newsprint')                      38.75
# ('SS_MRF', 'Corr_Cardboard')                 38.44
# ('SS_MRF', 'Office_Paper')                   38.75
# ('SS_MRF', 'Magazines')                      38.75
# ('SS_MRF', 'Third_Class_Mail')               38.75
# ('SS_MRF', 'Folding_Containers')             38.75
# ('SS_MRF', 'Paper_Bags')                     38.75
# ('SS_MRF', 'Mixed_Paper')                    38.75
# ('SS_MRF', 'Paper_Non_recyclable')           39.14
# ('SS_MRF', 'HDPE_Translucent_Containers')    83.14
# ('SS_MRF', 'HDPE_Pigmented_Containers')      83.14
# ('SS_MRF', 'PET_Containers')                 48.63
# ('SS_MRF', 'Plastic_Other_1_Polypropylene')  39.14
# ('SS_MRF', 'Plastic_Other_2')                39.14
# ('SS_MRF', 'Mixed_Plastic')                  39.14
# ('SS_MRF', 'Plastic_Film')                   39.47
# ('SS_MRF', 'Plastic_Non_Recyclable')         39.14
# ('SS_MRF', 'Ferrous_Cans')                   51.59
# ('SS_MRF', 'Ferrous_Metal_Other')            51.59
# ('SS_MRF', 'Aluminum_Cans')                  49.65
# ('SS_MRF', 'Aluminum_Foil')                  49.65
# ('SS_MRF', 'Aluminum_Other')                 49.65
# ('SS_MRF', 'Ferrous_Non_recyclable')         51.59
# ('SS_MRF', 'Al_Non_recyclable')              49.65
# ('SS_MRF', 'Glass_Brown')                    50.50
# ('SS_MRF', 'Glass_Green')                    50.50
# ('SS_MRF', 'Glass_Clear')                    50.50
# ('SS_MRF', 'Mixed_Glass')                    50.38
# ('SS_MRF', 'Glass_Non_recyclable')           50.38
# ('SS_MRF', 'Misc_Organic')                   39.14
# ('SS_MRF', 'Misc_Inorganic')                 39.14
# ('SS_MRF', 'E_waste')                        39.14
# ('SS_MRF', 'Bottom_Ash')                     39.14
# ('SS_MRF', 'Fly_Ash')                        39.14
# ('SS_MRF', 'Diapers_and_sanitary_products')  39.14
#
#                                              ('SwolfPy_Operational_Cost', 'SwolfPy')  \
# ('SS_MRF', 'Yard_Trimmings_Leaves')          13.63
# ('SS_MRF', 'Yard_Trimmings_Grass')           13.63
# ('SS_MRF', 'Yard_Trimmings_Branches')        13.63
# ('SS_MRF', 'Food_Waste_Vegetable')           13.63
# ('SS_MRF', 'Food_Waste_Non_Vegetable')       13.63
# ('SS_MRF', 'Wood')                           13.63
# ('SS_MRF', 'Wood_Other')                     13.63
# ('SS_MRF', 'Textiles')                       13.63
# ('SS_MRF', 'Rubber_Leather')                 13.63
# ('SS_MRF', 'Newsprint')                      16.13
# ('SS_MRF', 'Corr_Cardboard')                 10.97
# ('SS_MRF', 'Office_Paper')                   16.13
# ('SS_MRF', 'Magazines')                      16.13
# ('SS_MRF', 'Third_Class_Mail')               16.13
# ('SS_MRF', 'Folding_Containers')             16.13
# ('SS_MRF', 'Paper_Bags')                     16.13
# ('SS_MRF', 'Mixed_Paper')                    16.13
# ('SS_MRF', 'Paper_Non_recyclable')           13.63
# ('SS_MRF', 'HDPE_Translucent_Containers')    55.72
# ('SS_MRF', 'HDPE_Pigmented_Containers')      55.72
# ('SS_MRF', 'PET_Containers')                 26.06
# ('SS_MRF', 'Plastic_Other_1_Polypropylene')  13.63
# ('SS_MRF', 'Plastic_Other_2')                13.63
# ('SS_MRF', 'Mixed_Plastic')                  13.63
# ('SS_MRF', 'Plastic_Film')                   15.61
# ('SS_MRF', 'Plastic_Non_Recyclable')         13.63
# ('SS_MRF', 'Ferrous_Cans')                   28.79
# ('SS_MRF', 'Ferrous_Metal_Other')            28.79
# ('SS_MRF', 'Aluminum_Cans')                  26.41
# ('SS_MRF', 'Aluminum_Foil')                  26.41
# ('SS_MRF', 'Aluminum_Other')                 26.41
# ('SS_MRF', 'Ferrous_Non_recyclable')         28.79
# ('SS_MRF', 'Al_Non_recyclable')              26.41
# ('SS_MRF', 'Glass_Brown')                    24.56
# ('SS_MRF', 'Glass_Green')                    24.56
# ('SS_MRF', 'Glass_Clear')                    24.56
# ('SS_MRF', 'Mixed_Glass')                    22.58
# ('SS_MRF', 'Glass_Non_recyclable')           22.58
# ('SS_MRF', 'Misc_Organic')                   13.63
# ('SS_MRF', 'Misc_Inorganic')                 13.63
# ('SS_MRF', 'E_waste')                        13.63
# ('SS_MRF', 'Bottom_Ash')                     13.63
# ('SS_MRF', 'Fly_Ash')                        13.63
# ('SS_MRF', 'Diapers_and_sanitary_products')  13.63
#
#                                              ('SwolfPy_Capital_Cost', 'SwolfPy')  \
# ('SS_MRF', 'Yard_Trimmings_Leaves')          9.89
# ('SS_MRF', 'Yard_Trimmings_Grass')           9.89
# ('SS_MRF', 'Yard_Trimmings_Branches')        9.89
# ('SS_MRF', 'Food_Waste_Vegetable')           9.89
# ('SS_MRF', 'Food_Waste_Non_Vegetable')       9.89
# ('SS_MRF', 'Wood')                           9.89
# ('SS_MRF', 'Wood_Other')                     9.89
# ('SS_MRF', 'Textiles')                       9.89
# ('SS_MRF', 'Rubber_Leather')                 9.89
# ('SS_MRF', 'Newsprint')                      9.89
# ('SS_MRF', 'Corr_Cardboard')                 9.89
# ('SS_MRF', 'Office_Paper')                   9.89
# ('SS_MRF', 'Magazines')                      9.89
# ('SS_MRF', 'Third_Class_Mail')               9.89
# ('SS_MRF', 'Folding_Containers')             9.89
# ('SS_MRF', 'Paper_Bags')                     9.89
# ('SS_MRF', 'Mixed_Paper')                    9.89
# ('SS_MRF', 'Paper_Non_recyclable')           9.89
# ('SS_MRF', 'HDPE_Translucent_Containers')    9.89
# ('SS_MRF', 'HDPE_Pigmented_Containers')      9.89
# ('SS_MRF', 'PET_Containers')                 9.89
# ('SS_MRF', 'Plastic_Other_1_Polypropylene')  9.89
# ('SS_MRF', 'Plastic_Other_2')                9.89
# ('SS_MRF', 'Mixed_Plastic')                  9.89
# ('SS_MRF', 'Plastic_Film')                   9.89
# ('SS_MRF', 'Plastic_Non_Recyclable')         9.89
# ('SS_MRF', 'Ferrous_Cans')                   9.89
# ('SS_MRF', 'Ferrous_Metal_Other')            9.89
# ('SS_MRF', 'Aluminum_Cans')                  9.89
# ('SS_MRF', 'Aluminum_Foil')                  9.89
# ('SS_MRF', 'Aluminum_Other')                 9.89
# ('SS_MRF', 'Ferrous_Non_recyclable')         9.89
# ('SS_MRF', 'Al_Non_recyclable')              9.89
# ('SS_MRF', 'Glass_Brown')                    9.89
# ('SS_MRF', 'Glass_Green')                    9.89
# ('SS_MRF', 'Glass_Clear')                    9.89
# ('SS_MRF', 'Mixed_Glass')                    9.89
# ('SS_MRF', 'Glass_Non_recyclable')           9.89
# ('SS_MRF', 'Misc_Organic')                   9.89
# ('SS_MRF', 'Misc_Inorganic')                 9.89
# ('SS_MRF', 'E_waste')                        9.89
# ('SS_MRF', 'Bottom_Ash')                     9.89
# ('SS_MRF', 'Fly_Ash')                        9.89
# ('SS_MRF', 'Diapers_and_sanitary_products')  9.89
#
#                                              ('SwolfPy_Total_Cost', 'SwolfPy')
# ('SS_MRF', 'Yard_Trimmings_Leaves')          23.51
# ('SS_MRF', 'Yard_Trimmings_Grass')           23.51
# ('SS_MRF', 'Yard_Trimmings_Branches')        23.51
# ('SS_MRF', 'Food_Waste_Vegetable')           23.51
# ('SS_MRF', 'Food_Waste_Non_Vegetable')       23.51
# ('SS_MRF', 'Wood')                           23.51
# ('SS_MRF', 'Wood_Other')                     23.51
# ('SS_MRF', 'Textiles')                       23.51
# ('SS_MRF', 'Rubber_Leather')                 23.51
# ('SS_MRF', 'Newsprint')                      26.02
# ('SS_MRF', 'Corr_Cardboard')                 20.86
# ('SS_MRF', 'Office_Paper')                   26.02
# ('SS_MRF', 'Magazines')                      26.02
# ('SS_MRF', 'Third_Class_Mail')               26.02
# ('SS_MRF', 'Folding_Containers')             26.02
# ('SS_MRF', 'Paper_Bags')                     26.02
# ('SS_MRF', 'Mixed_Paper')                    26.02
# ('SS_MRF', 'Paper_Non_recyclable')           23.51
# ('SS_MRF', 'HDPE_Translucent_Containers')    65.61
# ('SS_MRF', 'HDPE_Pigmented_Containers')      65.61
# ('SS_MRF', 'PET_Containers')                 35.94
# ('SS_MRF', 'Plastic_Other_1_Polypropylene')  23.51
# ('SS_MRF', 'Plastic_Other_2')                23.51
# ('SS_MRF', 'Mixed_Plastic')                  23.51
# ('SS_MRF', 'Plastic_Film')                   25.50
# ('SS_MRF', 'Plastic_Non_Recyclable')         23.51
# ('SS_MRF', 'Ferrous_Cans')                   38.68
# ('SS_MRF', 'Ferrous_Metal_Other')            38.68
# ('SS_MRF', 'Aluminum_Cans')                  36.30
# ('SS_MRF', 'Aluminum_Foil')                  36.30
# ('SS_MRF', 'Aluminum_Other')                 36.30
# ('SS_MRF', 'Ferrous_Non_recyclable')         38.68
# ('SS_MRF', 'Al_Non_recyclable')              36.30
# ('SS_MRF', 'Glass_Brown')                    34.45
# ('SS_MRF', 'Glass_Green')                    34.45
# ('SS_MRF', 'Glass_Clear')                    34.45
# ('SS_MRF', 'Mixed_Glass')                    32.46
# ('SS_MRF', 'Glass_Non_recyclable')           32.46
# ('SS_MRF', 'Misc_Organic')                   23.51
# ('SS_MRF', 'Misc_Inorganic')                 23.51
# ('SS_MRF', 'E_waste')                        23.51
# ('SS_MRF', 'Bottom_Ash')                     23.51
# ('SS_MRF', 'Fly_Ash')                        23.51
# ('SS_MRF', 'Diapers_and_sanitary_products')  23.51
