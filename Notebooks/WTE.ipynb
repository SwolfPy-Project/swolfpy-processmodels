# %% [markdown]
# # Waste to Energy (WTE)

# %%
# Import libraries
from swolfpy_processmodels import WTE
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Set font for plots
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "12"

# Set specs for pandas
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
model = WTE()
model.calc()
report = model.report()

# %% [markdown]
# ## Energy Balance

# %%
Energy = pd.DataFrame(index=[x.replace('_', ' ') for x in model.Index])

Energy['Produced Electricity'] =  model.Energy_Calculations['Energy_Recovered_as_Electricity'].values
Energy['Used Electricity'] = -model.Energy_Calculations['Electricity_Use'].values
Energy['Heat Recovered'] = model.Energy_Calculations['Heat_Recovered'].values / 3.6

fig, ax=plt.subplots(figsize=(15, 4))

Energy.plot(kind='bar', stacked=True, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Waste Products

# %%
Waste_products = pd.DataFrame(report['Waste']).transpose()
Waste_products
# Out:
#                                Bottom_Ash   Fly_Ash  Unreacted_Ash      Al  \
# Yard_Trimmings_Leaves          0.080940    0.017260  0.0            0.0000
# Yard_Trimmings_Grass           0.063175    0.016325  0.0            0.0000
# Yard_Trimmings_Branches        0.041135    0.015165  0.0            0.0000
# Food_Waste_Vegetable           0.046455    0.015445  0.0            0.0000
# Food_Waste_Non_Vegetable       0.057000    0.016000  0.0            0.0000
# Wood                           0.089300    0.017700  0.0            0.0000
# Wood_Other                     0.193800    0.023200  0.0            0.0000
# Textiles                       0.013300    0.013700  0.0            0.0000
# Rubber_Leather                 0.289750    0.028250  0.0            0.0000
# Newsprint                      0.017765    0.013935  0.0            0.0000
# Corr_Cardboard                 0.104500    0.018500  0.0            0.0000
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 4))
Waste_products.plot.bar(ax=ax)
ax.set_ylim((0, 1))
# Out:
# (0.0, 1.0)
