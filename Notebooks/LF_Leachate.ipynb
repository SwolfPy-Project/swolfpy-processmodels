# %%
# Import libraries
from swolfpy_processmodels import LF
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Set font for plots
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

# Set specs for pandas
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.precision', 2)

# %%
model = LF()
model.calc()

# %%
model.lcht_Qlty.iloc[:, [0, 3, 4, 5, 6, 7]]
# Out:
#                           Emission           Group          Allocation_base  \
# 0   TSS                             General         Solid Content
# 1   BOD5, Biological Oxygen Demand  General         Methane Yield
# 2   COD, Chemical Oxygen Demand     General         Biogenic Carbon Content
# 3   Ammonium, ion                   General         Nitrogen Content
# 4   Phosphate                       General         Phosphorus Content
# 5   Calcium, ion                    General         Solid Content
# 6   Chloride                        General         Solid Content
# 7   Magnesium                       General         Solid Content
# 8   Sodium                          General         Solid Content
# 9   Benzene                         Trace Organics  Solid Content
# 10  Chloroform                      Trace Organics  Solid Content
# 11  Benzene, ethyl-                 Trace Organics  Solid Content
# 12  Ethylene dichloride             Trace Organics  Solid Content
# 13  Methane, dichloro-              Trace Organics  Solid Content
# 14  Tetrachloroethene               Trace Organics  Solid Content
# 15  Toluene                         Trace Organics  Solid Content
# 16  Trichloroethene                 Trace Organics  Solid Content
# 17  Ethene, chloro-                 Trace Organics  Solid Content
# 18  Xylene                          Trace Organics  Solid Content
# 19  Arsenic, ion                    Heavy Metals    Solid Content
# 20  Barium                          Heavy Metals    Barium
# 21  Cadmium, ion                    Heavy Metals    Cadmium
# 22  Chromium, ion                   Heavy Metals    Solid Content
# 23  Copper, ion                     Heavy Metals    Copper
# 24  Lead                            Heavy Metals    Solid Content
# 25  Mercury                         Heavy Metals    Mercury
# 26  Nickel                          Heavy Metals    Solid Content
# 27  Selenium                        Heavy Metals    Selenium
# 28  Silver, ion                     Heavy Metals    Solid Content
# 29  Zinc, ion                       Heavy Metals    Zinc
#
#     Removal Efficiency (%)  Stage 1 (0-2 years, mg/L)  \
# 0   96.0                    6.00e+01
# 1   97.0                    1.30e+04
# 2   80.0                    1.50e+04
# 3   98.0                    1.00e+03
# 4   21.6                    1.40e+01
# 5   85.0                    1.00e+03
# 6   85.0                    2.50e+03
# 7   85.0                    3.00e+02
# 8   85.0                    7.00e+02
# 9   99.0                    6.50e-03
# 10  99.0                    3.00e-04
# 11  80.0                    2.00e-02
# 12  70.0                    5.00e-02
# 13  70.0                    3.00e-02
# 14  70.0                    1.00e-02
# 15  80.0                    1.60e-01
# 16  70.0                    5.00e-03
# 17  70.0                    5.00e-02
# 18  60.0                    5.00e-02
# 19  70.0                    3.00e-02
# 20  85.0                    5.00e-01
# 21  85.0                    1.20e-02
# 22  30.0                    7.00e-02
# 23  50.0                    1.20e-01
# 24  85.0                    6.00e-02
# 25  85.0                    4.00e-04
# 26  20.0                    7.00e-02
# 27  85.0                    1.00e-02
# 28  85.0                    8.00e-02
# 29  70.0                    4.00e+00
#
#     Stage 2 (3-10 years, mg/L)
# 0   6.00e+01
# 1   8.00e+03
# 2   1.20e+04
# 3   7.00e+02
# 4   1.40e+01
# 5   1.00e+03
# 6   2.00e+03
# 7   3.00e+02
# 8   5.00e+02
# 9   6.50e-03
# 10  3.00e-04
# 11  2.00e-02
# 12  5.00e-02
# 13  1.50e-02
# 14  1.00e-02
# 15  1.60e-01
# 16  5.00e-03
# 17  5.00e-02
# 18  5.00e-02
# 19  2.50e-02
# 20  3.00e-01
# 21  1.00e-02
# 22  6.00e-02
# 23  1.00e-01
# 24  4.00e-02
# 25  3.00e-04
# 26  6.00e-02
# 27  8.00e-03
# 28  7.00e-02
# 29  2.20e+00

# %%
model._param3[['Generated Leachate (m3/Mg MSW)']].head()
# Out:
#    Generated Leachate (m3/Mg MSW)
# 0  5.16e-03
# 1  4.80e-03
# 2  4.40e-03
# 3  4.00e-03
# 4  3.59e-03

# %%
model.lcht_conc.head()
# Out:
#         TSS  BOD5, Biological Oxygen Demand  COD, Chemical Oxygen Demand  \
# 0  6.00e-05  1.30e-02                        0.01
# 1  6.00e-05  1.30e-02                        0.01
# 2  6.00e-05  8.00e-03                        0.01
# 3  6.00e-05  8.00e-03                        0.01
# 4  6.00e-05  8.00e-03                        0.01
#
#    Ammonium, ion  Phosphate  Calcium, ion  Chloride  Magnesium    Sodium  \
# 0  1.00e-03       1.40e-05   1.00e-03      2.50e-03  3.00e-04   7.00e-04
# 1  1.00e-03       1.40e-05   1.00e-03      2.50e-03  3.00e-04   7.00e-04
# 2  7.00e-04       1.40e-05   1.00e-03      2.00e-03  3.00e-04   5.00e-04
# 3  7.00e-04       1.40e-05   1.00e-03      2.00e-03  3.00e-04   5.00e-04
# 4  7.00e-04       1.40e-05   1.00e-03      2.00e-03  3.00e-04   5.00e-04
#
#     Benzene  Chloroform  Benzene, ethyl-  Ethylene dichloride  \
# 0  6.50e-09  3.00e-10    2.00e-08         5.00e-08
# 1  6.50e-09  3.00e-10    2.00e-08         5.00e-08
# 2  6.50e-09  3.00e-10    2.00e-08         5.00e-08
# 3  6.50e-09  3.00e-10    2.00e-08         5.00e-08
# 4  6.50e-09  3.00e-10    2.00e-08         5.00e-08
#
#    Methane, dichloro-  Tetrachloroethene   Toluene  Trichloroethene   \
# 0  3.00e-08            1.00e-08           1.60e-07  5.00e-09
# 1  3.00e-08            1.00e-08           1.60e-07  5.00e-09
# 2  1.50e-08            1.00e-08           1.60e-07  5.00e-09
# 3  1.50e-08            1.00e-08           1.60e-07  5.00e-09
# 4  1.50e-08            1.00e-08           1.60e-07  5.00e-09
#
#    Ethene, chloro-    Xylene  Arsenic, ion    Barium  Cadmium, ion  \
# 0  5.00e-08         5.00e-08  3.00e-08      5.00e-07  1.20e-08
# 1  5.00e-08         5.00e-08  3.00e-08      5.00e-07  1.20e-08
# 2  5.00e-08         5.00e-08  2.50e-08      3.00e-07  1.00e-08
# 3  5.00e-08         5.00e-08  2.50e-08      3.00e-07  1.00e-08
# 4  5.00e-08         5.00e-08  2.50e-08      3.00e-07  1.00e-08
#
#    Chromium, ion  Copper, ion      Lead   Mercury    Nickel  Selenium  \
# 0  7.00e-08       1.20e-07     6.00e-08  4.00e-10  7.00e-08  1.00e-08
# 1  7.00e-08       1.20e-07     6.00e-08  4.00e-10  7.00e-08  1.00e-08
# 3  2.40e-07       4.00e-07     1.60e-07  1.20e-09  2.40e-07  3.20e-08
# 4  2.16e-07       3.59e-07     1.44e-07  1.08e-09  2.16e-07  2.88e-08
#
#    Silver, ion  Zinc, ion
# 0  4.13e-07     2.06e-05
# 1  3.84e-07     1.92e-05
# 2  3.08e-07     9.67e-06
# 3  2.80e-07     8.79e-06
# 4  2.52e-07     7.91e-06

# %%
pd.DataFrame(mass_lcht_emission.sum(), columns=['Mass in 100 years leachate (kg)'])
# Out:
#                                 Mass in 100 years leachate (kg)
# TSS                             9.04e-03
# BOD5, Biological Oxygen Demand  4.09e-01
# COD, Chemical Oxygen Demand     7.04e-01
# Ammonium, ion                   8.17e-02
# Phosphate                       2.11e-03
# Calcium, ion                    1.51e-01
# Chloride                        2.28e-01
# Magnesium                       4.52e-02
# Sodium                          5.78e-02
# Benzene                         9.79e-07
# Chloroform                      4.52e-08
# Benzene, ethyl-                 3.01e-06
# Ethylene dichloride             3.46e-06
# Methane, dichloro-              1.45e-06
# Tetrachloroethene               1.51e-06
# Toluene                         8.26e-06
# Trichloroethene                 9.80e-07
# Ethene, chloro-                 6.40e-06
# Xylene                          7.53e-06
# Arsenic, ion                    3.25e-06
# Barium                          3.42e-05
# Cadmium, ion                    1.22e-06
# Chromium, ion                   7.60e-06
# Copper, ion                     1.40e-05
# Lead                            3.34e-06
# Mercury                         3.49e-08
# Nickel                          7.60e-06
# Selenium                        9.99e-07
# Silver, ion                     5.30e-06
# Zinc, ion                       2.37e-04

# %%
def plot_cumulative(compound):
    cumlative = []
    j=0
    for i in mass_lcht_emission[compound]:
        j += i
        cumlative.append(j)
    fig, ax = plt.subplots(1, 1, figsize=(8, 5))
    ax.scatter(np.arange(1, 101), cumlative, label=compound, s=4)
    ax.set_xlabel('years after waste buried')
    ax.set_ylabel(f'{compound} (kg)')
    ax.axhline(0.95 * j, c='r', label='95% of total release')
    ax.axhline(0.99 * j, c='g', label='99% of total release')
    ax.legend()

# %%
plot_cumulative('BOD5, Biological Oxygen Demand')

# %%
plot_cumulative('COD, Chemical Oxygen Demand')

# %%
plot_cumulative('Phosphate')

# %%
plot_cumulative('TSS')

# %%
plot_cumulative('Barium')

# %% [markdown]
# ## Allocation of emissions

# %%
Group = 'General'
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
sns.heatmap(model.lcht_Alloc [model.lcht_Qlty['Emission'][model.lcht_Qlty['Group'] == Group]].T,
            cmap='flare', ax=ax)
# Out:
# <AxesSubplot:>

# %%
Group = 'Trace Organics'
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
sns.heatmap(model.lcht_Alloc [model.lcht_Qlty['Emission'][model.lcht_Qlty['Group'] == Group]].T,
            cmap='flare', ax=ax)
# Out:
# <AxesSubplot:>

# %%
Group = 'Heavy Metals'
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
sns.heatmap(model.lcht_Alloc [model.lcht_Qlty['Emission'][model.lcht_Qlty['Group'] == Group]].T,
            cmap='flare', ax=ax)
# Out:
# <AxesSubplot:>
